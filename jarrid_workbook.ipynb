# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import env

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ### Acquire

# %%
url = f'mysql+pymysql://{env.user}:{env.password}@{env.host}/curriculum_logs'
query = '''
Select * from logs
left join cohorts on logs.cohort_id = cohorts.id
ORDER BY date ASC, time ASC;
'''
df = pd.read_sql(query, url)

# %%
print(df.shape)
df.info()

# %%
#Dropping columns with an inordinate number of nulls (rendering variable essentially useless)
def drop_columns(df):
    df = df.drop(columns = [
        'updated_at',
        'deleted_at',
        'slack',
        'id'
    ],
    axis=1)
    return df


def handle_nulls(df):    
    # We keep % of the data after dropping nulls
    # round(df.dropna().shape[0] / df.shape[0], 4) returned ...
    df = df.dropna()
    return df

def parse_path(path):
    parts = path.split("/")
    output = {}
    if len(parts) == 1:
        output['primary_topic'] = parts[0]
        output['subtopic'] = 'None'
        output['tertiary'] = 'None'
    elif len(parts) == 2:
        output['primary_topic'] = parts[0]
        output['subtopic'] = parts[1]
        output['tertiary'] = 'None'
    else: 
        output['primary_topic'] = parts[0]
        output['subtopic'] = parts[1]
        output['tertiary'] = parts[2]
    return pd.Series(output)

# %%
df = drop_columns(df)

# %%
df = handle_nulls(df)

# %%
# Convert 

df.date = pd.to_datetime(df.date)
#df.time = pd.to_datetime(df.time)
df.start_date = pd.to_datetime(df.start_date)
df.end_date = pd.to_datetime(df.end_date)
df.created_at = pd.to_datetime(df.created_at)
#df['timestamp']=df.apply(lambda x:'%s-%s' % (x['date'],x['time']),axis=1)
#df.timestamp = pd.to_datetime(df.timestamp)
#df = df.drop(columns=['updated_at','created_at', 'id', 'deleted_at'])
df['cohort_id'] = df.cohort_id.astype(int)
#df['program_id'] = df.program_id.map({1: 'data_science', 2: 'web_dev'})

# %%
tf = df.path.apply(parse_path)

# %%
df = pd.concat([df, tf], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 847329 entries, 0 to 900222
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   date           847329 non-null  datetime64[ns]
#  1   time           847329 non-null  object
#  2   path           847329 non-null  object
#  3   user_id        847329 non-null  int64
#  4   cohort_id      847329 non-null  int64
#  5   ip             847329 non-null  object
#  6   name           847329 non-null  object
#  7   start_date     847329 non-null  datetime64[ns]
#  8   end_date       847329 non-null  datetime64[ns]
#  9   created_at     847329 non-null  datetime64[ns]
#  10  program_id     847329 non-null  float64
#  11  primary_topic  847329 non-null  object
#  12  subtopic       847329 non-null  object
#  13  tertiary       847329 non-null  object
# dtypes: datetime64[ns](4), float64(1), int64(2), object(7)
# memory usage: 97.0+ MB

# %%
df.head(20)
# Out:
#          date      time                                               path  \
# 0  2018-01-26  09:55:03                                                  /
# 1  2018-01-26  09:56:02                                            java-ii
# 2  2018-01-26  09:56:05                java-ii/object-oriented-programming
# 3  2018-01-26  09:56:06                 slides/object_oriented_programming
# 4  2018-01-26  09:56:24                          javascript-i/conditionals
# 5  2018-01-26  09:56:41                                 javascript-i/loops
# 6  2018-01-26  09:56:46                          javascript-i/conditionals
# 7  2018-01-26  09:56:48                             javascript-i/functions
# 8  2018-01-26  09:56:59                                 javascript-i/loops
# 9  2018-01-26  09:58:26                             javascript-i/functions
# 10 2018-01-26  09:59:22                           mkdocs/search_index.json
# 11 2018-01-26  10:00:02  javascript-i/introduction/working-with-data-ty...
# 12 2018-01-26  10:00:37                                                  /
# 13 2018-01-26  10:00:39                                       javascript-i
# 14 2018-01-26  10:00:44  javascript-i/introduction/working-with-data-ty...
# 15 2018-01-26  10:00:49                javascript-i/introduction/variables
# 16 2018-01-26  10:00:57                javascript-i/introduction/operators
# 17 2018-01-26  10:01:12  javascript-i/introduction/working-with-data-ty...
# 18 2018-01-26  10:02:02                             javascript-i/functions
# 19 2018-01-26  10:02:21                             javascript-i/functions
#
#     user_id  cohort_id            ip     name start_date   end_date  \
# 0         1          8  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 1         1          8  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2         1          8  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 3         1          8  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 4         2         22  97.105.19.61    Teddy 2018-01-08 2018-05-17
# 5         2         22  97.105.19.61    Teddy 2018-01-08 2018-05-17
# 6         3         22  97.105.19.61    Teddy 2018-01-08 2018-05-17
# 7         3         22  97.105.19.61    Teddy 2018-01-08 2018-05-17
# 8         2         22  97.105.19.61    Teddy 2018-01-08 2018-05-17
# 9         4         22  97.105.19.61    Teddy 2018-01-08 2018-05-17
# 10        5         22  97.105.19.61    Teddy 2018-01-08 2018-05-17
# 11        6         22  97.105.19.61    Teddy 2018-01-08 2018-05-17
# 12        6         22  97.105.19.61    Teddy 2018-01-08 2018-05-17
# 13        6         22  97.105.19.61    Teddy 2018-01-08 2018-05-17
# 14        6         22  97.105.19.61    Teddy 2018-01-08 2018-05-17
# 15        6         22  97.105.19.61    Teddy 2018-01-08 2018-05-17
# 16        6         22  97.105.19.61    Teddy 2018-01-08 2018-05-17
# 17        6         22  97.105.19.61    Teddy 2018-01-08 2018-05-17
# 18        7         22  97.105.19.61    Teddy 2018-01-08 2018-05-17
# 19        8         22  97.105.19.61    Teddy 2018-01-08 2018-05-17
#
#             created_at  program_id primary_topic                     subtopic  \
# 0  2016-06-14 19:52:26         1.0
# 1  2016-06-14 19:52:26         1.0       java-ii                         None
# 2  2016-06-14 19:52:26         1.0       java-ii  object-oriented-programming
# 3  2016-06-14 19:52:26         1.0        slides  object_oriented_programming
# 4  2018-01-08 13:59:10         2.0  javascript-i                 conditionals
# 5  2018-01-08 13:59:10         2.0  javascript-i                        loops
# 6  2018-01-08 13:59:10         2.0  javascript-i                 conditionals
# 7  2018-01-08 13:59:10         2.0  javascript-i                    functions
# 8  2018-01-08 13:59:10         2.0  javascript-i                        loops
# 9  2018-01-08 13:59:10         2.0  javascript-i                    functions
# 10 2018-01-08 13:59:10         2.0        mkdocs            search_index.json
# 11 2018-01-08 13:59:10         2.0  javascript-i                 introduction
# 12 2018-01-08 13:59:10         2.0
# 13 2018-01-08 13:59:10         2.0  javascript-i                         None
# 14 2018-01-08 13:59:10         2.0  javascript-i                 introduction
# 15 2018-01-08 13:59:10         2.0  javascript-i                 introduction
# 16 2018-01-08 13:59:10         2.0  javascript-i                 introduction
# 17 2018-01-08 13:59:10         2.0  javascript-i                 introduction
# 18 2018-01-08 13:59:10         2.0  javascript-i                    functions
# 19 2018-01-08 13:59:10         2.0  javascript-i                    functions
#
#                                            tertiary
# 0                                              None
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                              None
# 5                                              None
# 6                                              None
# 7                                              None
# 8                                              None
# 9                                              None
# 10                                             None
# 11  working-with-data-types-operators-and-variables
# 12                                             None
# 13                                             None
# 14  working-with-data-types-operators-and-variables
# 15                                        variables
# 16                                        operators
# 17  working-with-data-types-operators-and-variables
# 18                                             None
# 19                                             None

# %% [markdown]
# ### retrive observations after cohort end date

# %%
# Code of page vists after time with codeup counts
(df.date > df.end_date).value_counts()

# %%
after_grad = df[(df.date > df.end_date)]

# %%
(after_grad.date > after_grad.end_date).value_counts()
# Out:
# True    199834
# dtype: int64

# %%
full_stack_php = after_grad[after_grad.program_id == 1]
full_stack_java = after_grad[after_grad.program_id == 2]
data_science = after_grad[after_grad.program_id == 3]
front_end = after_grad[after_grad.program_id == 4]

# %% [markdown]
# #### Php

# %%
full_stack_php

# %%
full_stack_php.groupby(['program_id', 'path', 'primary_topic', 'subtopic', 'tertiary' ]).agg(['count']).reset_index().sort_values(by=[('user_id', 'count')], ascending=False).head(25)
# Out:
#     program_id                                               path  \
#
# 0          1.0                                                  /
# 506        1.0                                         index.html
# 544        1.0                                       javascript-i
# 483        1.0                                           html-css
# 676        1.0                                             spring
# 533        1.0                                           java-iii
# 520        1.0                                            java-ii
# 512        1.0                                             java-i
# 567        1.0                                      javascript-ii
# 64         1.0                                           appendix
# 576        1.0                                             jquery
# 595        1.0                                              mysql
# 216        1.0                                   content/html-css
# 560        1.0  javascript-i/introduction/working-with-data-ty...
# 540        1.0                                  java-iii/servlets
# 561        1.0                  javascript-i/javascript-with-html
# 691        1.0                          spring/fundamentals/views
# 537        1.0                              java-iii/jsp-and-jstl
# 554        1.0                             javascript-i/functions
# 687        1.0                   spring/fundamentals/repositories
# 293        1.0                              content/laravel/intro
# 538        1.0                                       java-iii/mvc
# 501        1.0                                  html-css/elements
# 536        1.0                                      java-iii/jdbc
# 553        1.0                          javascript-i/conditionals
#
#      primary_topic              subtopic  \
#
# 0
# 506     index.html                  None
# 544   javascript-i                  None
# 483       html-css                  None
# 676         spring                  None
# 533       java-iii                  None
# 520        java-ii                  None
# 512         java-i                  None
# 567  javascript-ii                  None
# 64        appendix                  None
# 576         jquery                  None
# 595          mysql                  None
# 216        content              html-css
# 560   javascript-i          introduction
# 540       java-iii              servlets
# 561   javascript-i  javascript-with-html
# 691         spring          fundamentals
# 537       java-iii          jsp-and-jstl
# 554   javascript-i             functions
# 687         spring          fundamentals
# 293        content               laravel
# 538       java-iii                   mvc
# 501       html-css              elements
# 536       java-iii                  jdbc
# 553   javascript-i          conditionals
#
#                                             tertiary  date  time user_id  \
#                                                      count count   count
# 0                                               None  1681  1681    1681
# 506                                             None  1011  1011    1011
# 544                                             None   736   736     736
# 483                                             None   542   542     542
# 676                                             None   501   501     501
# 533                                             None   479   479     479
# 520                                             None   454   454     454
# 512                                             None   444   444     444
# 567                                             None   429   429     429
# 64                                              None   409   409     409
# 576                                             None   344   344     344
# 595                                             None   284   284     284
# 216                                             None   262   262     262
# 560  working-with-data-types-operators-and-variables   232   232     232
# 540                                             None   227   227     227
# 561                                             None   225   225     225
# 691                                            views   225   225     225
# 537                                             None   224   224     224
# 554                                             None   220   220     220
# 687                                     repositories   217   217     217
# 293                                            intro   210   210     210
# 538                                             None   202   202     202
# 501                                             None   201   201     201
# 536                                             None   198   198     198
# 553                                             None   197   197     197
#
#     cohort_id    ip  name start_date end_date created_at
#         count count count      count    count      count
# 0        1681  1681  1681       1681     1681       1681
# 506      1011  1011  1011       1011     1011       1011
# 544       736   736   736        736      736        736
# 483       542   542   542        542      542        542
# 676       501   501   501        501      501        501
# 533       479   479   479        479      479        479
# 520       454   454   454        454      454        454
# 512       444   444   444        444      444        444
# 567       429   429   429        429      429        429
# 64        409   409   409        409      409        409
# 576       344   344   344        344      344        344
# 595       284   284   284        284      284        284
# 216       262   262   262        262      262        262
# 560       232   232   232        232      232        232
# 540       227   227   227        227      227        227
# 561       225   225   225        225      225        225
# 691       225   225   225        225      225        225
# 537       224   224   224        224      224        224
# 554       220   220   220        220      220        220
# 687       217   217   217        217      217        217
# 293       210   210   210        210      210        210
# 538       202   202   202        202      202        202
# 501       201   201   201        201      201        201
# 536       198   198   198        198      198        198
# 553       197   197   197        197      197        197

# %% [markdown]
# *** Takeaways**
#
# Top 5 lessons visited by Full Stack Php program graduates:
# - index.html
# - javascript-i
# - html-css
# - spring
# - java-iii

# %%
full_stack_php.name.value_counts()
# Out:
# Lassen        9587
# Arches        8890
# Olympic       4954
# Kings         2845
# Hampton       1712
# Quincy        1237
# Glacier        598
# Joshua         302
# Ike            253
# Badlands        93
# Franklin        72
# Denali           4
# Everglades       1
# Name: name, dtype: int64

# %%
php_primary_count = (full_stack_php.groupby('name').primary_topic.value_counts())
php_primary_count

# %%
full_stack_php.groupby('name').primary_topic.describe()

# %%
php_primary = pd.DataFrame(php_primary_count)
php_primary

# %%
php_primary['primary_topic']

# %% [markdown]
# #### Java

# %%
full_stack_java.groupby(['program_id', 'path', 'primary_topic', 'subtopic', 'tertiary' ]).agg(['count']).reset_index().sort_values(by=[('user_id', 'count')], ascending=False).head(25)
# Out:
#      program_id                                 path  primary_topic  \
#
# 1           2.0                                    /
# 1333        2.0                         javascript-i   javascript-i
# 1543        2.0                               spring         spring
# 1509        2.0             search/search_index.json         search
# 1264        2.0                             html-css       html-css
# 1319        2.0                             java-iii       java-iii
# 1307        2.0                              java-ii        java-ii
# 1300        2.0                               java-i         java-i
# 702         2.0                             appendix       appendix
# 1362        2.0                        javascript-ii  javascript-ii
# 1633        2.0                                  toc            toc
# 1409        2.0                                mysql          mysql
# 1375        2.0                               jquery         jquery
# 1553        2.0     spring/fundamentals/repositories         spring
# 1549        2.0      spring/fundamentals/controllers         spring
# 1557        2.0            spring/fundamentals/views         spring
# 1559        2.0                         spring/setup         spring
# 1378        2.0              jquery/ajax/weather-map         jquery
# 1330        2.0                    java-iii/servlets       java-iii
# 1283        2.0                    html-css/elements       html-css
# 1552        2.0    spring/fundamentals/relationships         spring
# 1323        2.0                java-iii/jsp-and-jstl       java-iii
# 1306        2.0    java-i/syntax-types-and-variables         java-i
# 1303        2.0          java-i/introduction-to-java         java-i
# 1318        2.0  java-ii/object-oriented-programming        java-ii
#
#                          subtopic       tertiary   date   time user_id  \
#                                                   count  count   count
# 1                                           None  12406  12406   12406
# 1333                         None           None   4229   4229    4229
# 1543                         None           None   3760   3760    3760
# 1509            search_index.json           None   3562   3562    3562
# 1264                         None           None   3136   3136    3136
# 1319                         None           None   3058   3058    3058
# 1307                         None           None   2985   2985    2985
# 1300                         None           None   2679   2679    2679
# 702                          None           None   2662   2662    2662
# 1362                         None           None   2549   2549    2549
# 1633                         None           None   2412   2412    2412
# 1409                         None           None   2290   2290    2290
# 1375                         None           None   2120   2120    2120
# 1553                 fundamentals   repositories   1495   1495    1495
# 1549                 fundamentals    controllers   1486   1486    1486
# 1557                 fundamentals          views   1473   1473    1473
# 1559                        setup           None   1391   1391    1391
# 1378                         ajax    weather-map   1293   1293    1293
# 1330                     servlets           None   1123   1123    1123
# 1283                     elements           None   1053   1053    1053
# 1552                 fundamentals  relationships   1028   1028    1028
# 1323                 jsp-and-jstl           None   1008   1008    1008
# 1306   syntax-types-and-variables           None    980    980     980
# 1303         introduction-to-java           None    972    972     972
# 1318  object-oriented-programming           None    967    967     967
#
#      cohort_id     ip   name start_date end_date created_at
#          count  count  count      count    count      count
# 1        12406  12406  12406      12406    12406      12406
# 1333      4229   4229   4229       4229     4229       4229
# 1543      3760   3760   3760       3760     3760       3760
# 1509      3562   3562   3562       3562     3562       3562
# 1264      3136   3136   3136       3136     3136       3136
# 1319      3058   3058   3058       3058     3058       3058
# 1307      2985   2985   2985       2985     2985       2985
# 1300      2679   2679   2679       2679     2679       2679
# 702       2662   2662   2662       2662     2662       2662
# 1362      2549   2549   2549       2549     2549       2549
# 1633      2412   2412   2412       2412     2412       2412
# 1409      2290   2290   2290       2290     2290       2290
# 1375      2120   2120   2120       2120     2120       2120
# 1553      1495   1495   1495       1495     1495       1495
# 1549      1486   1486   1486       1486     1486       1486
# 1557      1473   1473   1473       1473     1473       1473
# 1559      1391   1391   1391       1391     1391       1391
# 1378      1293   1293   1293       1293     1293       1293
# 1330      1123   1123   1123       1123     1123       1123
# 1283      1053   1053   1053       1053     1053       1053
# 1552      1028   1028   1028       1028     1028       1028
# 1323      1008   1008   1008       1008     1008       1008
# 1306       980    980    980        980      980        980
# 1303       972    972    972        972      972        972
# 1318       967    967    967        967      967        967

# %% [markdown]
# *** Takeaways**
#
# Top 5 lessons visited by Full Stack Java program graduates:
# - javascript-i
# - spring
# - search/search_index.json
# - html-css
# - java-iii

# %%
full_stack_java.name
# Out:
# 72          Niagara
# 73          Niagara
# 112       Pinnacles
# 113       Pinnacles
# 116       Pinnacles
#             ...
# 900218        Staff
# 900219        Staff
# 900220        Staff
# 900221        Staff
# 900222        Staff
# Name: name, Length: 157786, dtype: object

# %%
java_primary_count = (full_stack_java.groupby('name').primary_topic.value_counts())
java_primary_count

# %%
pd.DataFrame(java_primary_count)

# %% [markdown]
# #### Data Science

# %%
data_science
# Out:
#              date      time  \
# 443671 2020-01-31  11:05:04
# 443672 2020-01-31  11:05:13
# 443673 2020-01-31  11:05:13
# 443674 2020-01-31  11:05:13
# 443948 2020-01-31  14:44:59
# ...           ...       ...
# 900093 2021-04-21  15:20:12
# 900094 2021-04-21  15:20:12
# 900095 2021-04-21  15:20:12
# 900096 2021-04-21  15:20:14
# 900097 2021-04-21  15:20:18
#
#                                                      path  user_id  cohort_id  \
# 443671                                                  /      476         34
# 443672           1-fundamentals/1.1-intro-to-data-science      476         34
# 443673           1-fundamentals/modern-data-scientist.jpg      476         34
# 443674               1-fundamentals/AI-ML-DL-timeline.jpg      476         34
# 443948                                                  /      476         34
# ...                                                   ...      ...        ...
# 900093           classification/scale_features_or_not.svg      692         59
# 900094  classification/classical_programming_vs_machin...      692         59
# 900095                            classification/overview      692         59
# 900096                             classification/project      692         59
# 900097                             classification/acquire      692         59
#
#                    ip    name start_date   end_date          created_at  \
# 443671  136.50.49.145   Bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 443672  136.50.49.145   Bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 443673  136.50.49.145   Bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 443674  136.50.49.145   Bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 443948  136.50.49.145   Bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# ...               ...     ...        ...        ...                 ...
# 900093   96.8.130.134  Darden 2020-07-13 2021-01-12 2020-07-13 18:32:19
# 900094   96.8.130.134  Darden 2020-07-13 2021-01-12 2020-07-13 18:32:19
# 900095   96.8.130.134  Darden 2020-07-13 2021-01-12 2020-07-13 18:32:19
# 900096   96.8.130.134  Darden 2020-07-13 2021-01-12 2020-07-13 18:32:19
# 900097   96.8.130.134  Darden 2020-07-13 2021-01-12 2020-07-13 18:32:19
#
#         program_id   primary_topic  \
# 443671         3.0
# 443672         3.0  1-fundamentals
# 443673         3.0  1-fundamentals
# 443674         3.0  1-fundamentals
# 443948         3.0
# ...            ...             ...
# 900093         3.0  classification
# 900094         3.0  classification
# 900095         3.0  classification
# 900096         3.0  classification
# 900097         3.0  classification
#
#                                               subtopic tertiary
# 443671                                                     None
# 443672                       1.1-intro-to-data-science     None
# 443673                       modern-data-scientist.jpg     None
# 443674                           AI-ML-DL-timeline.jpg     None
# 443948                                                     None
# ...                                                ...      ...
# 900093                       scale_features_or_not.svg     None
# 900094  classical_programming_vs_machine_learning.jpeg     None
# 900095                                        overview     None
# 900096                                         project     None
# 900097                                         acquire     None
#
# [11495 rows x 14 columns]

# %%
data_science.drop(['start_date', 'end_date', 'created_at'], axis =1, inplace=True)

# %%
data_science.groupby(['program_id', 'path', 'primary_topic', 'subtopic', 'tertiary' ]).agg(['count']).reset_index().sort_values(by=[('user_id', 'count')], ascending=False).head(25)
# Out:
#     program_id                                               path  \
#
# 0          3.0                                                  /
# 371        3.0                           search/search_index.json
# 388        3.0                                 sql/mysql-overview
# 252        3.0                            classification/overview
# 257        3.0           classification/scale_features_or_not.svg
# 194        3.0     anomaly-detection/AnomalyDetectionCartoon.jpeg
# 199        3.0                         anomaly-detection/overview
# 284        3.0                 fundamentals/AI-ML-DL-timeline.jpg
# 305        3.0             fundamentals/modern-data-scientist.jpg
# 302        3.0                 fundamentals/intro-to-data-science
# 15         3.0           1-fundamentals/modern-data-scientist.jpg
# 1          3.0           1-fundamentals/1.1-intro-to-data-science
# 13         3.0               1-fundamentals/AI-ML-DL-timeline.jpg
# 126        3.0                            6-regression/1-overview
# 378        3.0                                sql/database-design
# 242        3.0  classification/classical_programming_vs_machin...
# 253        3.0                                classification/prep
# 299        3.0                     fundamentals/environment-setup
# 397        3.0                                stats/compare-means
# 425        3.0                                 timeseries/acquire
# 315        3.0                                        nlp/acquire
# 427        3.0                        timeseries/modeling-lesson1
# 16         3.0                    10-anomaly-detection/1-overview
# 21         3.0  10-anomaly-detection/AnomalyDetectionCartoon.jpeg
# 385        3.0                                 sql/more-exercises
#
#             primary_topic                                        subtopic  \
#
# 0
# 371                search                               search_index.json
# 388                   sql                                  mysql-overview
# 252        classification                                        overview
# 257        classification                       scale_features_or_not.svg
# 194     anomaly-detection                    AnomalyDetectionCartoon.jpeg
# 199     anomaly-detection                                        overview
# 284          fundamentals                           AI-ML-DL-timeline.jpg
# 305          fundamentals                       modern-data-scientist.jpg
# 302          fundamentals                           intro-to-data-science
# 15         1-fundamentals                       modern-data-scientist.jpg
# 1          1-fundamentals                       1.1-intro-to-data-science
# 13         1-fundamentals                           AI-ML-DL-timeline.jpg
# 126          6-regression                                      1-overview
# 378                   sql                                 database-design
# 242        classification  classical_programming_vs_machine_learning.jpeg
# 253        classification                                            prep
# 299          fundamentals                               environment-setup
# 397                 stats                                   compare-means
# 425            timeseries                                         acquire
# 315                   nlp                                         acquire
# 427            timeseries                                modeling-lesson1
# 16   10-anomaly-detection                                      1-overview
# 21   10-anomaly-detection                    AnomalyDetectionCartoon.jpeg
# 385                   sql                                  more-exercises
#
#     tertiary  date  time user_id cohort_id    ip  name
#              count count   count     count count count
# 0       None  1436  1436    1436      1436  1436  1436
# 371     None   493   493     493       493   493   493
# 388     None   275   275     275       275   275   275
# 252     None   266   266     266       266   266   266
# 257     None   219   219     219       219   219   219
# 194     None   193   193     193       193   193   193
# 199     None   191   191     191       191   191   191
# 284     None   189   189     189       189   189   189
# 305     None   187   187     187       187   187   187
# 302     None   184   184     184       184   184   184
# 15      None   127   127     127       127   127   127
# 1       None   126   126     126       126   126   126
# 13      None   126   126     126       126   126   126
# 126     None    86    86      86        86    86    86
# 378     None    84    84      84        84    84    84
# 242     None    80    80      80        80    80    80
# 253     None    77    77      77        77    77    77
# 299     None    76    76      76        76    76    76
# 397     None    73    73      73        73    73    73
# 425     None    72    72      72        72    72    72
# 315     None    72    72      72        72    72    72
# 427     None    71    71      71        71    71    71
# 16      None    69    69      69        69    69    69
# 21      None    69    69      69        69    69    69
# 385     None    66    66      66        66    66    66

# %% [markdown]
# *** Takeaways**
#
# Top 5 lessons visited by Data Scientisit program graduates:
# - search/search_index.json
# - sql/mysql-overview
# - classification/overview
# - classification/scale_features_or_not.svg
# - anomaly-detection/AnomalyDetectionCartoon.jpeg

# %%
df1 = data_science.groupby(['name', 'primary_topic', 'subtopic', 'tertiary' ]).agg(['count']).reset_index()

# %%
df1
# Out:
#        name   primary_topic                       subtopic tertiary  date  \
#                                                                     count
# 0     Bayes                                                    None   491
# 1     Bayes  1-fundamentals      1.1-intro-to-data-science     None   114
# 2     Bayes  1-fundamentals      1.2-data-science-pipeline     None     9
# 3     Bayes  1-fundamentals              1.3-pipeline-demo     None     4
# 4     Bayes  1-fundamentals             2.1-excel-overview     None     3
# ..      ...             ...                            ...      ...   ...
# 872  Darden      timeseries               modeling-lesson1     None    24
# 873  Darden      timeseries                       overview     None    11
# 874  Darden      timeseries                           prep     None    11
# 875  Darden      timeseries                        project     None     7
# 876  Darden      timeseries  working-with-time-series-data     None    27
#
#      time  path user_id cohort_id    ip program_id
#     count count   count     count count      count
# 0     491   491     491       491   491        491
# 1     114   114     114       114   114        114
# 2       9     9       9         9     9          9
# 3       4     4       4         4     4          4
# 4       3     3       3         3     3          3
# ..    ...   ...     ...       ...   ...        ...
# 872    24    24      24        24    24         24
# 873    11    11      11        11    11         11
# 874    11    11      11        11    11         11
# 875     7     7       7         7     7          7
# 876    27    27      27        27    27         27
#
# [877 rows x 11 columns]

# %%
df1.sort_values(by=[('user_id', 'count')], ascending=False).head(25)
# Out:
#        name      primary_topic                      subtopic tertiary  date  \
#                                                                       count
# 400   Curie                                                      None   564
# 0     Bayes                                                      None   491
# 685  Darden                                                      None   381
# 340   Bayes             search             search_index.json     None   187
# 627   Curie             search             search_index.json     None   157
# 824  Darden             search             search_index.json     None   149
# 535   Curie     classification                      overview     None   136
# 641   Curie                sql                mysql-overview     None   125
# 837  Darden                sql                mysql-overview     None   123
# 15    Bayes     1-fundamentals     modern-data-scientist.jpg     None   115
# 1     Bayes     1-fundamentals     1.1-intro-to-data-science     None   114
# 13    Bayes     1-fundamentals         AI-ML-DL-timeline.jpg     None   114
# 697  Darden  anomaly-detection  AnomalyDetectionCartoon.jpeg     None   105
# 702  Darden  anomaly-detection                      overview     None   104
# 555   Curie       fundamentals         AI-ML-DL-timeline.jpg     None   101
# 573   Curie       fundamentals     modern-data-scientist.jpg     None   100
# 539   Curie     classification     scale_features_or_not.svg     None    96
# 571   Curie       fundamentals         intro-to-data-science     None    96
# 742  Darden     classification                      overview     None    95
# 746  Darden     classification     scale_features_or_not.svg     None    95
# 126   Bayes       6-regression                    1-overview     None    77
# 489   Curie  anomaly-detection  AnomalyDetectionCartoon.jpeg     None    74
# 493   Curie  anomaly-detection                      overview     None    72
# 764  Darden       fundamentals         AI-ML-DL-timeline.jpg     None    64
# 780  Darden       fundamentals         intro-to-data-science     None    63
#
#      time  path user_id cohort_id    ip program_id
#     count count   count     count count      count
# 400   564   564     564       564   564        564
# 0     491   491     491       491   491        491
# 685   381   381     381       381   381        381
# 340   187   187     187       187   187        187
# 627   157   157     157       157   157        157
# 824   149   149     149       149   149        149
# 535   136   136     136       136   136        136
# 641   125   125     125       125   125        125
# 837   123   123     123       123   123        123
# 15    115   115     115       115   115        115
# 1     114   114     114       114   114        114
# 13    114   114     114       114   114        114
# 697   105   105     105       105   105        105
# 702   104   104     104       104   104        104
# 555   101   101     101       101   101        101
# 573   100   100     100       100   100        100
# 539    96    96      96        96    96         96
# 571    96    96      96        96    96         96
# 742    95    95      95        95    95         95
# 746    95    95      95        95    95         95
# 126    77    77      77        77    77         77
# 489    74    74      74        74    74         74
# 493    72    72      72        72    72         72
# 764    64    64      64        64    64         64
# 780    63    63      63        63    63         63

# %%
df1.columns
# Out:
# MultiIndex([(         'name',      ''),
#             ('primary_topic',      ''),
#             (     'subtopic',      ''),
#             (     'tertiary',      ''),
#             (         'date', 'count'),
#             (         'time', 'count'),
#             (         'path', 'count'),
#             (      'user_id', 'count'),
#             (    'cohort_id', 'count'),
#             (           'ip', 'count'),
#             (   'start_date', 'count'),
#             (     'end_date', 'count'),
#             (   'created_at', 'count'),
#             (   'program_id', 'count')],
#            )

# %%
df1['name'].value_counts()
# Out:
# Bayes     400
# Curie     285
# Darden    192
# Name: name, dtype: int64

# %%
# Splits each cohort into a separate dataframe
bayes = df1.loc[df1['name'] == 'Bayes']
curie = df1.loc[df1['name'] == 'Curie']
darden = df1.loc[df1['name'] == 'Darden']

# %%
# Splits each cohort into a separate dataframe
bayes = data_science.loc[data_science['name'] == 'Bayes']
curie = data_science.loc[data_science['name'] == 'Curie']
darden = data_science.loc[data_science['name'] == 'Darden']

# %%
bayes.sort_values(by=[('user_id', 'count')], ascending=False).head(25)
# Out:
#       name         primary_topic                      subtopic tertiary  date  \
#                                                                         count
# 0    Bayes                                                         None   491
# 340  Bayes                search             search_index.json     None   187
# 15   Bayes        1-fundamentals     modern-data-scientist.jpg     None   115
# 13   Bayes        1-fundamentals         AI-ML-DL-timeline.jpg     None   114
# 1    Bayes        1-fundamentals     1.1-intro-to-data-science     None   114
# 126  Bayes          6-regression                    1-overview     None    77
# 21   Bayes  10-anomaly-detection  AnomalyDetectionCartoon.jpeg     None    48
# 16   Bayes  10-anomaly-detection                    1-overview     None    48
# 66   Bayes                 3-sql              1-mysql-overview     None    40
# 138  Bayes          6-regression                     7.0-model     None    39
# 36   Bayes     12-distributed-ml                   3-spark-api     None    36
# 237  Bayes        classification                      overview     None    35
# 147  Bayes      7-classification                        3-prep     None    35
# 134  Bayes          6-regression                  5.0-evaluate     None    34
# 238  Bayes        classification                          prep     None    33
# 148  Bayes      7-classification                     4-explore     None    33
# 72   Bayes                 3-sql                   3-databases     None    33
# 73   Bayes                 3-sql                      4-tables     None    30
# 150  Bayes      7-classification       6.1-logistic-regression     None    30
# 151  Bayes      7-classification            6.2-decision-trees     None    30
# 25   Bayes                11-nlp                     3-acquire     None    30
# 71   Bayes                 3-sql          2-mysql-introduction     None    29
# 170  Bayes          9-timeseries                        3-prep     None    29
# 117  Bayes               5-stats             4.2-compare-means     None    29
# 128  Bayes          6-regression          2.0-acquire-and-prep     None    29
#
#      time  path user_id cohort_id    ip program_id
#     count count   count     count count      count
# 0     491   491     491       491   491        491
# 340   187   187     187       187   187        187
# 15    115   115     115       115   115        115
# 13    114   114     114       114   114        114
# 1     114   114     114       114   114        114
# 126    77    77      77        77    77         77
# 21     48    48      48        48    48         48
# 16     48    48      48        48    48         48
# 66     40    40      40        40    40         40
# 138    39    39      39        39    39         39
# 36     36    36      36        36    36         36
# 237    35    35      35        35    35         35
# 147    35    35      35        35    35         35
# 134    34    34      34        34    34         34
# 238    33    33      33        33    33         33
# 148    33    33      33        33    33         33
# 72     33    33      33        33    33         33
# 73     30    30      30        30    30         30
# 150    30    30      30        30    30         30
# 151    30    30      30        30    30         30
# 25     30    30      30        30    30         30
# 71     29    29      29        29    29         29
# 170    29    29      29        29    29         29
# 117    29    29      29        29    29         29
# 128    29    29      29        29    29         29

# %%
bayes.subtopic.value_counts()
# Out:
# None                                     22
# cli                                      16
# project                                  10
# 1-overview                               10
# overview                                 10
#                                          ..
# 4.3-correlation                           1
# 4.4-compare-group-membership              1
# 4.5-more-statistical-testing-examples     1
# 5-power-analysis                          1
# working-with-time-series-data             1
# Name: subtopic, Length: 284, dtype: int64

# %% [markdown]
# *** Takeaways**
#
# - Top 5 lessons Bayes graduates visited:
#     - search	search_index.json
#     - 1-fundamentals	modern-data-scientist.jpg
#     - 1-fundamentals	AI-ML-DL-timeline.jpg
#     - 1-fundamentals	1.1-intro-to-data-science
#     - 6-regression	1-overview

# %%
curie.sort_values(by=[('user_id', 'count')], ascending=False).head(25)
# Out:
#       name      primary_topic                      subtopic tertiary  date  \
#                                                                      count
# 400  Curie                                                      None   564
# 627  Curie             search             search_index.json     None   157
# 535  Curie     classification                      overview     None   136
# 641  Curie                sql                mysql-overview     None   125
# 555  Curie       fundamentals         AI-ML-DL-timeline.jpg     None   101
# 573  Curie       fundamentals     modern-data-scientist.jpg     None   100
# 539  Curie     classification     scale_features_or_not.svg     None    96
# 571  Curie       fundamentals         intro-to-data-science     None    96
# 489  Curie  anomaly-detection  AnomalyDetectionCartoon.jpeg     None    74
# 493  Curie  anomaly-detection                      overview     None    72
# 632  Curie                sql               database-design     None    56
# 679  Curie         timeseries                          prep     None    27
# 536  Curie     classification                          prep     None    27
# 578  Curie                nlp                       acquire     None    27
# 674  Curie         timeseries                       acquire     None    27
# 505  Curie           appendix          ds-environment-setup     None    26
# 593  Curie             python                    dataframes     None    25
# 441  Curie           4-python                   5-functions     None    25
# 556  Curie       fundamentals           DataToAction_v2.jpg     None    23
# 675  Curie         timeseries                       explore     None    23
# 587  Curie                nlp           regular-expressions     None    23
# 531  Curie     classification                    evaluation     None    23
# 568  Curie       fundamentals             environment-setup     None    22
# 676  Curie         timeseries              modeling-lesson1     None    22
# 547  Curie         clustering                       wrangle     None    22
#
#      time  path user_id cohort_id    ip program_id
#     count count   count     count count      count
# 400   564   564     564       564   564        564
# 627   157   157     157       157   157        157
# 535   136   136     136       136   136        136
# 641   125   125     125       125   125        125
# 555   101   101     101       101   101        101
# 573   100   100     100       100   100        100
# 539    96    96      96        96    96         96
# 571    96    96      96        96    96         96
# 489    74    74      74        74    74         74
# 493    72    72      72        72    72         72
# 632    56    56      56        56    56         56
# 679    27    27      27        27    27         27
# 536    27    27      27        27    27         27
# 578    27    27      27        27    27         27
# 674    27    27      27        27    27         27
# 505    26    26      26        26    26         26
# 593    25    25      25        25    25         25
# 441    25    25      25        25    25         25
# 556    23    23      23        23    23         23
# 675    23    23      23        23    23         23
# 587    23    23      23        23    23         23
# 531    23    23      23        23    23         23
# 568    22    22      22        22    22         22
# 676    22    22      22        22    22         22
# 547    22    22      22        22    22         22

# %% [markdown]
# *** Takeaways**
#
# - Top 5 lessons Curie graduates visited:
#     - search	search_index.json
#     - classification	overview
#     - sql	mysql-overview
#     - fundamentals	AI-ML-DL-timeline.jpg
#     - fundamentals	modern-data-scientist.jpg

# %%
darden.sort_values(by=[('user_id', 'count')], ascending=False).head(25)
# Out:
#        name      primary_topic  \
#
# 685  Darden
# 824  Darden             search
# 837  Darden                sql
# 697  Darden  anomaly-detection
# 702  Darden  anomaly-detection
# 742  Darden     classification
# 746  Darden     classification
# 764  Darden       fundamentals
# 782  Darden       fundamentals
# 780  Darden       fundamentals
# 734  Darden     classification
# 715  Darden           appendix
# 835  Darden                sql
# 777  Darden       fundamentals
# 790  Darden                nlp
# 870  Darden         timeseries
# 805  Darden             python
# 797  Darden                nlp
# 846  Darden              stats
# 876  Darden         timeseries
# 840  Darden                sql
# 830  Darden                sql
# 872  Darden         timeseries
# 833  Darden                sql
# 826  Darden                sql
#
#                                            subtopic tertiary  date  time  \
#                                                              count count
# 685                                                     None   381   381
# 824                               search_index.json     None   149   149
# 837                                  mysql-overview     None   123   123
# 697                    AnomalyDetectionCartoon.jpeg     None   105   105
# 702                                        overview     None   104   104
# 742                                        overview     None    95    95
# 746                       scale_features_or_not.svg     None    95    95
# 764                           AI-ML-DL-timeline.jpg     None    64    64
# 782                       modern-data-scientist.jpg     None    63    63
# 780                           intro-to-data-science     None    63    63
# 734  classical_programming_vs_machine_learning.jpeg     None    56    56
# 715                                        postwork     None    54    54
# 835                                  more-exercises     None    47    47
# 777                               environment-setup     None    45    45
# 790                                         acquire     None    37    37
# 870                                         acquire     None    35    35
# 805                             intro-to-matplotlib     None    34    34
# 797                             regular-expressions     None    31    31
# 846                                   compare-means     None    30    30
# 876                   working-with-time-series-data     None    27    27
# 840                                      subqueries     None    26    26
# 830                                       functions     None    26    26
# 872                                modeling-lesson1     None    24    24
# 833                                           joins     None    23    23
# 826                                 case-statements     None    22    22
#
#      path user_id cohort_id    ip program_id
#     count   count     count count      count
# 685   381     381       381   381        381
# 824   149     149       149   149        149
# 837   123     123       123   123        123
# 697   105     105       105   105        105
# 702   104     104       104   104        104
# 742    95      95        95    95         95
# 746    95      95        95    95         95
# 764    64      64        64    64         64
# 782    63      63        63    63         63
# 780    63      63        63    63         63
# 734    56      56        56    56         56
# 715    54      54        54    54         54
# 835    47      47        47    47         47
# 777    45      45        45    45         45
# 790    37      37        37    37         37
# 870    35      35        35    35         35
# 805    34      34        34    34         34
# 797    31      31        31    31         31
# 846    30      30        30    30         30
# 876    27      27        27    27         27
# 840    26      26        26    26         26
# 830    26      26        26    26         26
# 872    24      24        24    24         24
# 833    23      23        23    23         23
# 826    22      22        22    22         22

# %% [markdown]
# *** Takeaways**
#
# - Top 5 lessons Darden graduates visited:
#     - search	search_index.json
#     - sql	mysql-overview
#     - anomaly-detection	AnomalyDetectionCartoon.jpeg
#     - anomaly-detection	overview
#     - classification	overview

# %% [markdown]
# #### Frontend

# %%
front_end

# %%
front_end.groupby(['program_id', 'path', 'primary_topic', 'subtopic', 'tertiary' ]).agg(['count']).reset_index().sort_values(by=[('user_id', 'count')], ascending=False).head(25)
# Out:
#   program_id                                         path primary_topic  \
#
# 1        4.0                             content/html-css       content
# 0        4.0                                            /
# 2        4.0  content/html-css/gitbook/images/favicon.ico       content
# 3        4.0           content/html-css/introduction.html       content
#
#    subtopic           tertiary  date  time user_id cohort_id    ip  name  \
#                                count count   count     count count count
# 1  html-css               None     2     2       2         2     2     2
# 0                         None     1     1       1         1     1     1
# 2  html-css            gitbook     1     1       1         1     1     1
# 3  html-css  introduction.html     1     1       1         1     1     1
#
#   start_date end_date created_at
#        count    count      count
# 1          2        2          2
# 0          1        1          1
# 2          1        1          1
# 3          1        1          1

# %% [markdown]
# ** Takeaways **
#
# Front End progarm graduates only have 5 observations since graduating. Not enough data to see what top lessons visited by program.

# %% [markdown]
# ### Extra code

# %%
df[(df.date > df.end_date)].groupby(['name','program_id', 'primary_topic', 'subtopic', 'tertiary']).value_counts()

# %%
pd.DataFrame(df[(df.date > df.end_date)].groupby(['name','program_id', 'primary_topic', 'subtopic', 'tertiary']).value_counts())

# %%
#df[(df.date > df.end_date)].groupby(['program_id', 'primary_topic', 'subtopic', 'tertiary']).value_counts().plot.barh(figsize=(5,5))

# %% [markdown]
# ### Observations that occurred after 2019

# %%
(df.date >= '2019-01-01').value_counts()
# Out:
# True     675820
# False    171509
# Name: date, dtype: int64

# %%
after_2019 = df[(df.date >= '2019-01-01')]

# %%
after_2019.head()
# Out:
#              date      time            path  user_id  cohort_id  \
# 175808 2019-01-01  07:45:45    java-iii/mvc      271         26
# 175809 2019-01-01  12:20:53               /       51         13
# 175810 2019-01-01  12:56:12          java-i      274         26
# 175811 2019-01-01  12:59:46  java-i/strings      274         26
# 175812 2019-01-01  15:25:49  java-i/methods      274         26
#
#                    ip    name start_date   end_date          created_at  \
# 175808  73.31.215.224  Xanadu 2018-09-17 2019-02-08 2018-09-17 19:09:51
# 175809  72.179.161.39   Kings 2016-05-23 2016-09-15 2016-06-14 19:52:26
# 175810    67.11.239.2  Xanadu 2018-09-17 2019-02-08 2018-09-17 19:09:51
# 175811    67.11.239.2  Xanadu 2018-09-17 2019-02-08 2018-09-17 19:09:51
# 175812    67.11.239.2  Xanadu 2018-09-17 2019-02-08 2018-09-17 19:09:51
#
#         program_id primary_topic subtopic tertiary
# 175808         2.0      java-iii      mvc     None
# 175809         1.0                            None
# 175810         2.0        java-i     None     None
# 175811         2.0        java-i  strings     None
# 175812         2.0        java-i  methods     None

# %%
# Dictionary of path url for web dev program
web_dev_path= pd.DataFrame(after_2019[after_2019.program_id != 3].path.unique())
web_dev_path.rename({0 : 'path'}, axis=1, inplace=True)
web_dev_path
# Out:
#                                                    path
# 0                                          java-iii/mvc
# 1                                                     /
# 2                                                java-i
# 3                                        java-i/strings
# 4                                        java-i/methods
# ...                                                 ...
# 1901                                                css
# 1902                      easley-python-assessment.html
# 1903                    florence-python-assessment.html
# 1904                                   javascript-i/dom
# 1905  appendix/professional-development/post-intervi...
#
# [1906 rows x 1 columns]

# %%
# Dictionary of path url for data science program
ds_path = pd.DataFrame(after_2019[after_2019.program_id == 3].path.unique())
ds_path.rename({0 : 'path'}, axis=1, inplace=True)
ds_path
# Out:
#                                                   path
# 0                                                    /
# 1                               3-sql/1-mysql-overview
# 2                            2-storytelling/bad-charts
# 3              2-storytelling/misleading1_baseball.jpg
# 4                   2-storytelling/misleading1_fox.jpg
# ..                                                 ...
# 677  clustering/hierarchical_circle.png!%5Bimage.pn...
# 678              individual-project/individual-project
# 679                         classification/explore-old
# 680                    florence-python-assessment.html
# 681                                         dataframes
#
# [682 rows x 1 columns]

# %%
after_2019['ds_hit'] = after_2019['path'].isin(ds_path['path'])

# %%
after_2019['web_dev_hit'] = after_2019['path'].isin(web_dev_path['path'])

# %%
after_2019['both_programs'] =  (after_2019.ds_hit == after_2019.web_dev_hit)

# %%
after_2019
# Out:
#              date      time                                              path  \
# 175808 2019-01-01  07:45:45                                      java-iii/mvc
# 175809 2019-01-01  12:20:53                                                 /
# 175810 2019-01-01  12:56:12                                            java-i
# 175811 2019-01-01  12:59:46                                    java-i/strings
# 175812 2019-01-01  15:25:49                                    java-i/methods
# ...           ...       ...                                               ...
# 900218 2021-04-21  16:41:51                              jquery/personal-site
# 900219 2021-04-21  16:42:02                                 jquery/mapbox-api
# 900220 2021-04-21  16:42:09                           jquery/ajax/weather-map
# 900221 2021-04-21  16:44:37  anomaly-detection/discrete-probabilistic-methods
# 900222 2021-04-21  16:44:39                                 jquery/mapbox-api
#
#         user_id  cohort_id             ip    name start_date   end_date  \
# 175808      271         26  73.31.215.224  Xanadu 2018-09-17 2019-02-08
# 175809       51         13  72.179.161.39   Kings 2016-05-23 2016-09-15
# 175810      274         26    67.11.239.2  Xanadu 2018-09-17 2019-02-08
# 175811      274         26    67.11.239.2  Xanadu 2018-09-17 2019-02-08
# 175812      274         26    67.11.239.2  Xanadu 2018-09-17 2019-02-08
# ...         ...        ...            ...     ...        ...        ...
# 900218       64         28  71.150.217.33   Staff 2014-02-04 2014-02-04
# 900219       64         28  71.150.217.33   Staff 2014-02-04 2014-02-04
# 900220       64         28  71.150.217.33   Staff 2014-02-04 2014-02-04
# 900221      744         28  24.160.137.86   Staff 2014-02-04 2014-02-04
# 900222       64         28  71.150.217.33   Staff 2014-02-04 2014-02-04
#
#                 created_at  program_id      primary_topic  \
# 175808 2018-09-17 19:09:51         2.0           java-iii
# 175809 2016-06-14 19:52:26         1.0
# 175810 2018-09-17 19:09:51         2.0             java-i
# 175811 2018-09-17 19:09:51         2.0             java-i
# 175812 2018-09-17 19:09:51         2.0             java-i
# ...                    ...         ...                ...
# 900218 2018-12-06 17:04:19         2.0             jquery
# 900219 2018-12-06 17:04:19         2.0             jquery
# 900220 2018-12-06 17:04:19         2.0             jquery
# 900221 2018-12-06 17:04:19         2.0  anomaly-detection
# 900222 2018-12-06 17:04:19         2.0             jquery
#
#                               subtopic     tertiary  ds_hit  web_dev_hit  \
# 175808                             mvc         None   False         True
# 175809                                         None    True         True
# 175810                            None         None    True         True
# 175811                         strings         None   False         True
# 175812                         methods         None   False         True
# ...                                ...          ...     ...          ...
# 900218                   personal-site         None   False         True
# 900219                      mapbox-api         None   False         True
# 900220                            ajax  weather-map   False         True
# 900221  discrete-probabilistic-methods         None    True         True
# 900222                      mapbox-api         None   False         True
#
#         both_programs
# 175808          False
# 175809           True
# 175810           True
# 175811          False
# 175812          False
# ...               ...
# 900218          False
# 900219          False
# 900220          False
# 900221           True
# 900222          False
#
# [675820 rows x 17 columns]

# %%
after_2019[after_2019.both_programs == True]

# %%
after_2019[after_2019.path != '/']

# %%
after_2019[(after_2019.both_programs == True) & (after_2019.path != '/')]
# Out:
#              date      time                                              path  \
# 175810 2019-01-01  12:56:12                                            java-i
# 175814 2019-01-01  15:32:24                                               toc
# 175815 2019-01-01  15:32:26                                     javascript-ii
# 175816 2019-01-01  15:32:28                                            jquery
# 175819 2019-01-01  16:38:34                                          java-iii
# ...           ...       ...                                               ...
# 900214 2021-04-21  16:41:29                                      javascript-i
# 900215 2021-04-21  16:41:31                                     javascript-ii
# 900216 2021-04-21  16:41:49                                            jquery
# 900217 2021-04-21  16:41:51                      javascript-i/bom-and-dom/dom
# 900221 2021-04-21  16:44:37  anomaly-detection/discrete-probabilistic-methods
#
#         user_id  cohort_id              ip      name start_date   end_date  \
# 175810      274         26     67.11.239.2    Xanadu 2018-09-17 2019-02-08
# 175814      301         27  72.181.106.116  Yosemite 2018-11-05 2019-04-03
# 175815      301         27  72.181.106.116  Yosemite 2018-11-05 2019-04-03
# 175816      301         27  72.181.106.116  Yosemite 2018-11-05 2019-04-03
# 175819      262         26   97.105.90.179    Xanadu 2018-09-17 2019-02-08
# ...         ...        ...             ...       ...        ...        ...
# 900214       64         28   71.150.217.33     Staff 2014-02-04 2014-02-04
# 900215       64         28   71.150.217.33     Staff 2014-02-04 2014-02-04
# 900216       64         28   71.150.217.33     Staff 2014-02-04 2014-02-04
# 900217      875        135  24.242.150.231     Marco 2021-01-25 2021-07-19
# 900221      744         28   24.160.137.86     Staff 2014-02-04 2014-02-04
#
#                 created_at  program_id      primary_topic  \
# 175810 2018-09-17 19:09:51         2.0             java-i
# 175814 2018-11-05 15:26:37         2.0                toc
# 175815 2018-11-05 15:26:37         2.0      javascript-ii
# 175816 2018-11-05 15:26:37         2.0             jquery
# 175819 2018-09-17 19:09:51         2.0           java-iii
# ...                    ...         ...                ...
# 900214 2018-12-06 17:04:19         2.0       javascript-i
# 900215 2018-12-06 17:04:19         2.0      javascript-ii
# 900216 2018-12-06 17:04:19         2.0             jquery
# 900217 2021-01-20 21:31:11         2.0       javascript-i
# 900221 2018-12-06 17:04:19         2.0  anomaly-detection
#
#                               subtopic tertiary  ds_hit  web_dev_hit  \
# 175810                            None     None    True         True
# 175814                            None     None    True         True
# 175815                            None     None    True         True
# 175816                            None     None    True         True
# 175819                            None     None    True         True
# ...                                ...      ...     ...          ...
# 900214                            None     None    True         True
# 900215                            None     None    True         True
# 900216                            None     None    True         True
# 900217                     bom-and-dom      dom    True         True
# 900221  discrete-probabilistic-methods     None    True         True
#
#         both_programs
# 175810           True
# 175814           True
# 175815           True
# 175816           True
# 175819           True
# ...               ...
# 900214           True
# 900215           True
# 900216           True
# 900217           True
# 900221           True
#
# [273787 rows x 17 columns]

# %% [markdown]
# ***Takeaway***
#
# - Users does continue to have access to both curriculmns until April 21, 2021.

# %% [markdown]
# #### Observations prior to 2019

# %%
before_2019 = df[(df.date < '2019-01-01')]

# %%
before_2019['ds_hit'] = before_2019['path'].isin(ds_path['path'])

# %%
before_2019['web_dev_hit'] = before_2019['path'].isin(web_dev_path['path'])

# %%
before_2019['both_programs'] =  (before_2019.ds_hit == before_2019.web_dev_hit)

# %%
before_2019[(before_2019.both_programs == True) & (before_2019.path != '/')]
# Out:
#              date      time                                 path  user_id  \
# 1      2018-01-26  09:56:02                              java-ii        1
# 2      2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 4      2018-01-26  09:56:24            javascript-i/conditionals        2
# 6      2018-01-26  09:56:46            javascript-i/conditionals        3
# 13     2018-01-26  10:00:39                         javascript-i        6
# ...           ...       ...                                  ...      ...
# 175794 2018-12-31  15:59:42            javascript-i/conditionals      128
# 175801 2018-12-31  23:51:33                               spring      289
# 175802 2018-12-31  23:51:45                               java-i      289
# 175804 2018-12-31  23:51:56                             java-iii      289
# 175806 2018-12-31  23:52:20                        javascript-ii      289
#
#         cohort_id             ip      name start_date   end_date  \
# 1               8   97.105.19.61   Hampton 2015-09-22 2016-02-06
# 2               8   97.105.19.61   Hampton 2015-09-22 2016-02-06
# 4              22   97.105.19.61     Teddy 2018-01-08 2018-05-17
# 6              22   97.105.19.61     Teddy 2018-01-08 2018-05-17
# 13             22   97.105.19.61     Teddy 2018-01-08 2018-05-17
# ...           ...            ...       ...        ...        ...
# 175794         23  69.232.100.94   Ulysses 2018-03-05 2018-07-19
# 175801         27     98.6.94.51  Yosemite 2018-11-05 2019-04-03
# 175802         27     98.6.94.51  Yosemite 2018-11-05 2019-04-03
# 175804         27     98.6.94.51  Yosemite 2018-11-05 2019-04-03
# 175806         27     98.6.94.51  Yosemite 2018-11-05 2019-04-03
#
#                 created_at  program_id  primary_topic  \
# 1      2016-06-14 19:52:26         1.0        java-ii
# 2      2016-06-14 19:52:26         1.0        java-ii
# 4      2018-01-08 13:59:10         2.0   javascript-i
# 6      2018-01-08 13:59:10         2.0   javascript-i
# 13     2018-01-08 13:59:10         2.0   javascript-i
# ...                    ...         ...            ...
# 175794 2018-03-05 14:22:11         2.0   javascript-i
# 175801 2018-11-05 15:26:37         2.0         spring
# 175802 2018-11-05 15:26:37         2.0         java-i
# 175804 2018-11-05 15:26:37         2.0       java-iii
# 175806 2018-11-05 15:26:37         2.0  javascript-ii
#
#                            subtopic tertiary  ds_hit  web_dev_hit  \
# 1                              None     None    True         True
# 2       object-oriented-programming     None    True         True
# 4                      conditionals     None    True         True
# 6                      conditionals     None    True         True
# 13                             None     None    True         True
# ...                             ...      ...     ...          ...
# 175794                 conditionals     None    True         True
# 175801                         None     None    True         True
# 175802                         None     None    True         True
# 175804                         None     None    True         True
# 175806                         None     None    True         True
#
#         both_programs
# 1                True
# 2                True
# 4                True
# 6                True
# 13               True
# ...               ...
# 175794           True
# 175801           True
# 175802           True
# 175804           True
# 175806           True
#
# [41616 rows x 17 columns]

# %% [markdown]
# *** Takeaway ***
#
# - Users did have access both curriculum prior to the year 2019.
