# %% [markdown]
# # David's Working Notebook

# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import metrics


import joint_acquire
import joint_prepare
import env

# %%
df = joint_acquire.acquire_logs(user=env.user, password=env.password, host=env.host)
df
# Out:
#               date      time  \
# 0       2018-01-26  09:55:03
# 1       2018-01-26  09:56:02
# 2       2018-01-26  09:56:05
# 3       2018-01-26  09:56:06
# 4       2018-01-26  09:56:24
# ...            ...       ...
# 900218  2021-04-21  16:41:51
# 900219  2021-04-21  16:42:02
# 900220  2021-04-21  16:42:09
# 900221  2021-04-21  16:44:37
# 900222  2021-04-21  16:44:39
#
#                                                     path  user_id  cohort_id  \
# 0                                                      /        1        8.0
# 1                                                java-ii        1        8.0
# 2                    java-ii/object-oriented-programming        1        8.0
# 3                     slides/object_oriented_programming        1        8.0
# 4                              javascript-i/conditionals        2       22.0
# ...                                                  ...      ...        ...
# 900218                              jquery/personal-site       64       28.0
# 900219                                 jquery/mapbox-api       64       28.0
# 900220                           jquery/ajax/weather-map       64       28.0
# 900221  anomaly-detection/discrete-probabilistic-methods      744       28.0
# 900222                                 jquery/mapbox-api       64       28.0
#
#                    ip    id     name     slack  start_date    end_date  \
# 0        97.105.19.61   8.0  Hampton  #hampton  2015-09-22  2016-02-06
# 1        97.105.19.61   8.0  Hampton  #hampton  2015-09-22  2016-02-06
# 2        97.105.19.61   8.0  Hampton  #hampton  2015-09-22  2016-02-06
# 3        97.105.19.61   8.0  Hampton  #hampton  2015-09-22  2016-02-06
# 4        97.105.19.61  22.0    Teddy    #teddy  2018-01-08  2018-05-17
# ...               ...   ...      ...       ...         ...         ...
# 900218  71.150.217.33  28.0    Staff         #  2014-02-04  2014-02-04
# 900219  71.150.217.33  28.0    Staff         #  2014-02-04  2014-02-04
# 900220  71.150.217.33  28.0    Staff         #  2014-02-04  2014-02-04
# 900221  24.160.137.86  28.0    Staff         #  2014-02-04  2014-02-04
# 900222  71.150.217.33  28.0    Staff         #  2014-02-04  2014-02-04
#
#                  created_at           updated_at deleted_at  program_id
# 0       2016-06-14 19:52:26  2016-06-14 19:52:26       None         1.0
# 1       2016-06-14 19:52:26  2016-06-14 19:52:26       None         1.0
# 2       2016-06-14 19:52:26  2016-06-14 19:52:26       None         1.0
# 3       2016-06-14 19:52:26  2016-06-14 19:52:26       None         1.0
# 4       2018-01-08 13:59:10  2018-01-08 13:59:10       None         2.0
# ...                     ...                  ...        ...         ...
# 900218  2018-12-06 17:04:19  2018-12-06 17:04:19       None         2.0
# 900219  2018-12-06 17:04:19  2018-12-06 17:04:19       None         2.0
# 900220  2018-12-06 17:04:19  2018-12-06 17:04:19       None         2.0
# 900221  2018-12-06 17:04:19  2018-12-06 17:04:19       None         2.0
# 900222  2018-12-06 17:04:19  2018-12-06 17:04:19       None         2.0
#
# [900223 rows x 15 columns]

# %%
df, df_admin = joint_prepare.prepare_logs(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/davidschneemann/codeup/curriculum-logs/david_working_notebook.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/davidschneemann/codeup/curriculum-logs/david_working_notebook.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df, df_admin = joint_prepare.prepare_logs(df, df.path)
#
# File ~/codeup/curriculum-logs/joint_prepare.py:74, in prepare_logs(df, path)
#      70 df_admin = create_ancillary_df(df)
#      72 df = handle_nulls(df)
# ---> 74 df = parse_path(path)
#      76 df = apply_path(df)
#      78 return df, df_admin
#
# File ~/codeup/curriculum-logs/joint_prepare.py:33, in parse_path(path)
#      31 def parse_path(path):
#      32     #
# ---> 33     parts = path.split("/")
#      34     output = {}
#      35     if len(parts) == 0:
#
# File /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
df.head()
# Out:
#          date      time                                 path  user_id  \
# 0  2018-01-26  09:55:03                                    /        1
# 1  2018-01-26  09:56:02                              java-ii        1
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 3  2018-01-26  09:56:06   slides/object_oriented_programming        1
# 4  2018-01-26  09:56:24            javascript-i/conditionals        2
#
#    cohort_id            ip     name  start_date    end_date  \
# 0        8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 1        8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 2        8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 3        8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 4       22.0  97.105.19.61    Teddy  2018-01-08  2018-05-17
#
#             created_at  program_id
# 0  2016-06-14 19:52:26         1.0
# 1  2016-06-14 19:52:26         1.0
# 2  2016-06-14 19:52:26         1.0
# 3  2016-06-14 19:52:26         1.0
# 4  2018-01-08 13:59:10         2.0

# %%
df_admin.head()
# Out:
#          date      time                                 path  user_id  \
# 0  2018-01-26  09:55:03                                    /        1
# 1  2018-01-26  09:56:02                              java-ii        1
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 3  2018-01-26  09:56:06   slides/object_oriented_programming        1
# 4  2018-01-26  09:56:24            javascript-i/conditionals        2
#
#    cohort_id            ip     name  start_date    end_date  \
# 0        8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 1        8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 2        8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 3        8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 4       22.0  97.105.19.61    Teddy  2018-01-08  2018-05-17
#
#             created_at  program_id
# 0  2016-06-14 19:52:26         1.0
# 1  2016-06-14 19:52:26         1.0
# 2  2016-06-14 19:52:26         1.0
# 3  2016-06-14 19:52:26         1.0
# 4  2018-01-08 13:59:10         2.0

# %%
df_admin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900223 entries, 0 to 900222
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        900223 non-null  object
#  1   time        900223 non-null  object
#  2   path        900222 non-null  object
#  3   user_id     900223 non-null  int64
#  4   cohort_id   847330 non-null  float64
#  5   ip          900223 non-null  object
#  6   name        847330 non-null  object
#  7   start_date  847330 non-null  object
#  8   end_date    847330 non-null  object
#  9   created_at  847330 non-null  object
#  10  program_id  847330 non-null  float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 75.5+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 847329 entries, 0 to 900222
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        847329 non-null  object
#  1   time        847329 non-null  object
#  2   path        847329 non-null  object
#  3   user_id     847329 non-null  int64
#  4   cohort_id   847329 non-null  float64
#  5   ip          847329 non-null  object
#  6   name        847329 non-null  object
#  7   start_date  847329 non-null  object
#  8   end_date    847329 non-null  object
#  9   created_at  847329 non-null  object
#  10  program_id  847329 non-null  float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 77.6+ MB

# %% [markdown]
# ## Acquire/Prep Setup

# %%
def parse_path(path):
    parts = path.split("/")
    output = {}
    if len(parts) == 0:
        output['primary_topic'] = 'None'
        output['subtopic'] = 'None'
        output['tertiary'] = 'None'
    if len(parts) == 1:
        output['primary_topic'] = parts[0]
        output['subtopic'] = 'None'
        output['tertiary'] = 'None'
    elif len(parts) == 2:
        output['primary_topic'] = parts[0]
        output['subtopic'] = parts[1]
        output['tertiary'] = 'None'
    else: 
        output['primary_topic'] = parts[0]
        output['subtopic'] = parts[1]
        output['tertiary'] = parts[2]
    return pd.Series(output)

# %% [markdown]
# def parse_path(df):
#     #
#     parts = df.path.split("/")
#     output = {}
#     if len(parts) == 0:
#         output['primary_topic'] = 'None'
#         output['subtopic'] = 'None'
#         output['tertiary'] = 'None'
#     elif len(parts) == 1:
#         output['primary_topic'] = parts[0]
#         output['subtopic'] = 'None'
#         output['tertiary'] = 'None'
#     elif len(parts) == 2:
#         output['primary_topic'] = parts[0]
#         output['subtopic'] = parts[1]
#         output['tertiary'] = 'None'
#     else:
#         output['primary_topic'] = parts[0]
#         output['subtopic'] = parts[1]
#         output['tertiary'] = parts[2]
#     return pd.DataFrame(output)

# %%
tf = df.path.apply(parse_path)

# %%
tf
# Out:
#             primary_topic                        subtopic     tertiary
# 0                                                                 None
# 1                 java-ii                            None         None
# 2                 java-ii     object-oriented-programming         None
# 3                  slides     object_oriented_programming         None
# 4            javascript-i                    conditionals         None
# ...                   ...                             ...          ...
# 900218             jquery                   personal-site         None
# 900219             jquery                      mapbox-api         None
# 900220             jquery                            ajax  weather-map
# 900221  anomaly-detection  discrete-probabilistic-methods         None
# 900222             jquery                      mapbox-api         None
#
# [847329 rows x 3 columns]

# %%
df.merge(tf, how = 'inner', left_index = True, right_index = True)
# Out:
#               date      time  \
# 0       2018-01-26  09:55:03
# 1       2018-01-26  09:56:02
# 2       2018-01-26  09:56:05
# 3       2018-01-26  09:56:06
# 4       2018-01-26  09:56:24
# ...            ...       ...
# 900218  2021-04-21  16:41:51
# 900219  2021-04-21  16:42:02
# 900220  2021-04-21  16:42:09
# 900221  2021-04-21  16:44:37
# 900222  2021-04-21  16:44:39
#
#                                                     path  user_id  cohort_id  \
# 0                                                      /        1        8.0
# 1                                                java-ii        1        8.0
# 2                    java-ii/object-oriented-programming        1        8.0
# 3                     slides/object_oriented_programming        1        8.0
# 4                              javascript-i/conditionals        2       22.0
# ...                                                  ...      ...        ...
# 900218                              jquery/personal-site       64       28.0
# 900219                                 jquery/mapbox-api       64       28.0
# 900220                           jquery/ajax/weather-map       64       28.0
# 900221  anomaly-detection/discrete-probabilistic-methods      744       28.0
# 900222                                 jquery/mapbox-api       64       28.0
#
#                    ip     name  start_date    end_date           created_at  \
# 0        97.105.19.61  Hampton  2015-09-22  2016-02-06  2016-06-14 19:52:26
# 1        97.105.19.61  Hampton  2015-09-22  2016-02-06  2016-06-14 19:52:26
# 2        97.105.19.61  Hampton  2015-09-22  2016-02-06  2016-06-14 19:52:26
# 3        97.105.19.61  Hampton  2015-09-22  2016-02-06  2016-06-14 19:52:26
# 4        97.105.19.61    Teddy  2018-01-08  2018-05-17  2018-01-08 13:59:10
# ...               ...      ...         ...         ...                  ...
# 900218  71.150.217.33    Staff  2014-02-04  2014-02-04  2018-12-06 17:04:19
# 900219  71.150.217.33    Staff  2014-02-04  2014-02-04  2018-12-06 17:04:19
# 900220  71.150.217.33    Staff  2014-02-04  2014-02-04  2018-12-06 17:04:19
# 900221  24.160.137.86    Staff  2014-02-04  2014-02-04  2018-12-06 17:04:19
# 900222  71.150.217.33    Staff  2014-02-04  2014-02-04  2018-12-06 17:04:19
#
#         program_id      primary_topic                        subtopic  \
# 0              1.0
# 1              1.0            java-ii                            None
# 2              1.0            java-ii     object-oriented-programming
# 3              1.0             slides     object_oriented_programming
# 4              2.0       javascript-i                    conditionals
# ...            ...                ...                             ...
# 900218         2.0             jquery                   personal-site
# 900219         2.0             jquery                      mapbox-api
# 900220         2.0             jquery                            ajax
# 900221         2.0  anomaly-detection  discrete-probabilistic-methods
# 900222         2.0             jquery                      mapbox-api
#
#            tertiary
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# ...             ...
# 900218         None
# 900219         None
# 900220  weather-map
# 900221         None
# 900222         None
#
# [847329 rows x 14 columns]
